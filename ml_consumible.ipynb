# %%
import pandas as pd 
from pycaret.regression import *

# %%
# Se carga el arhivo parquet
df= pd.read_parquet('dataset\\verde_final.parquet')

# %%
# Se configura la inicialización de Pycaret
s = setup(df,target='total_amount',session_id=123)
# Out:
# <style type="text/css">
# #T_5eead_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5eead">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5eead_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5eead_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5eead_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5eead_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5eead_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5eead_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5eead_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5eead_row1_col1" class="data row1 col1" >total_amount</td>
#     </tr>
#     <tr>
#       <th id="T_5eead_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Se crea el modelo Logistic Regression 
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_2f1b8_row10_col0, #T_2f1b8_row10_col1, #T_2f1b8_row10_col2, #T_2f1b8_row10_col3, #T_2f1b8_row10_col4, #T_2f1b8_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2f1b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f1b8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2f1b8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2f1b8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2f1b8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2f1b8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2f1b8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
# Se visualizan la importancia de las variables seleccionadas para el modelo
plot_model(lr,plot='feature')

# %%
# Se visualiza el margen de error para este modelo
plot_model(lr,plot='error')

# %%
# Se analizan los residuales en un gráfico
plot_model(lr,plot='residuals')

# %%
# Se guarda el modelo para hacer el deploy en streamlit
save_model(lr,model_name='deployment1')
